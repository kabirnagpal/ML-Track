# %% [markdown]
# ##  Hello Mentees

# %% [markdown]
# You might me aware about using jupyter notebook.
# It's simple to use and way more interactive than other compilers
# This writen here is language called Markdown which helps us make it more interactive

# %% [markdown]
# To run a code you need to click `Run`.
# * Note you can also run the complete file by clicking `Kernel`
#
# If any given moment your kernel stops responding restart and re-run the code using options from `Kernel`.
# You can also run a box by pressing `Shift`+`Enter`

# %% [markdown]
# # Week 1

# %% [markdown]
# Although week1 only introduction we'll stretch a little to cover it all.

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %% [markdown]
# Numpy is a mathematical library which helps us in most mathematical functions
# Before this let's get clarrified with arrays, lists and tupples
# #### Difference between Array List and Tuple
# ### Array
# An array is a contiguous memory allocation for data storage of same datatype. The static array always has a predefined size and it is efficient for iterative works as the elements are stored side by side in the dedicated memory locations. It is not that effective when it comes to inserting a new element in between the already present elements.
# Similarly, it causes inefficient memory management when you delete an element in between the elements present.
# To avoid the drawbacks of static arrays to a certain extent, the dynamic array was introduced and the data structures like vectors, array list and likewise fall under the dynamic array. These dynamic arrays can be resized, and they can be placed in a scattered manner in the memory space as per availability.
#
# ### List
# The concept of the dynamic array led to list or linked list as some like to call it. Unlike an array, a linked list is not continuous memory allocation. It has scatted memory allocation technique. Each node of a list consists of two parts. The first part contains the data while the second part is a pointer that had the memory reference of the next node wherever it is placed in the memory. This makes the memory management efficient in all scenarios and you can add or delete nodes in a list effortlessly with extremely high processing speed. Unlike an array, a list can have different data types.
#
# ### Tuple
# A tuple is an object that can contain heterogeneous data. Out of all data structures, a tuple is the fastest and they consume the least amount of memory. Like a static array, a tuple is fixed in size and that is why tuples are replacing array completely as they are more efficient in all parameters. If you have a dataset which will be assigned only once, and its value should not change again, you need a tuple.

# %%
a=[1,2,3]

# %%
type(a)
# Out:
# list

# %%
b=np.array(a)
type(b)
# Out:
# numpy.ndarray

# %%
len(b)
# Out:
# 3

# %%
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
b.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7566fbe11e6f> in <module>
# ----> 1 b.append(4)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %% [markdown]
# ### Find it out why this error occured?
# You can discuss it in the group

# %%
a.insert(4,5)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a.insert(0,7)
print(a)
# Out:
# [7, 1, 2, 3, 4, 5]

# %%
c=np.array([[1,2],[3,4]])
d=np.array([[2,2]])

# %% [markdown]
# ### Do refer the pdf shared

# %%
type(c)
# Out:
# numpy.ndarray

# %%
type(d)
# Out:
# numpy.ndarray

# %%
c*d
# Out:
# array([[2, 4],
#        [6, 8]])

# %%
c**d
# Out:
# array([[ 1,  4],
#        [ 9, 16]])

# %%
np.dot(c,d.T)
# Out:
# array([[ 6],
#        [14]])

# %% [markdown]
# Adding `.T` takes transpose of the matrix.

# %%
np.sum(c)
# Out:
# 10

# %%
np.log(c)
# Out:
# array([[0.        , 0.69314718],
#        [1.09861229, 1.38629436]])

# %%
c.max()
# Out:
# 4

# %%
c.mean()
# Out:
# 2.5

# %% [markdown]
# #### Do check out more functions
# You'll find the library to be easy to use.
# If at any given moment you're stuck,
# # Just GOOGLE it

# %% [markdown]
# # Pandas

# %% [markdown]
# This library is majorly used to deal with dataframes extracted from csv.
# Machine learning is used on a formated datasets.
# Collection of dataset  depends on the source.
# But as Data scientist you must know hoe to sort the data

# %%
import pandas as pd

# %% [markdown]
# data set source https://www.kaggle.com/geomack/spotifyclassification/downloads/spotifyclassification.zip/1

# %%
data=pd.read_csv('data/data_sound.csv')

# %%
data
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0      0.010200         0.833       204600   0.434
# 1              1      0.199000         0.743       326933   0.359
# 2              2      0.034400         0.838       185707   0.412
# 3              3      0.604000         0.494       199413   0.338
# 4              4      0.180000         0.678       392893   0.561
# 5              5      0.004790         0.804       251333   0.560
# 6              6      0.014500         0.739       241400   0.472
# 7              7      0.020200         0.266       349667   0.348
# 8              8      0.048100         0.603       202853   0.944
# 9              9      0.002080         0.836       226840   0.603
# 10            10      0.057200         0.525       358187   0.855
# 11            11      0.091500         0.753       324880   0.748
# 12            12      0.253000         0.603       356973   0.434
# 13            13      0.366000         0.762       243270   0.476
# 14            14      0.440000         0.662       247288   0.603
# 15            15      0.019000         0.637       188333   0.832
# 16            16      0.023900         0.603       270827   0.955
# 17            17      0.233000         0.789       447907   0.659
# 18            18      0.314000         0.713       195429   0.611
# 19            19      0.024200         0.735       214347   0.759
# 20            20      0.000702         0.854       249253   0.719
# 21            21      0.000240         0.747       307680   0.740
# 22            22      0.118000         0.854       287086   0.401
# 23            23      0.000596         0.224       132760   0.925
# 24            24      0.279000         0.512       203400   0.564
# 25            25      0.002190         0.781       205160   0.795
# 26            26      0.341000         0.411       199500   0.684
# 27            27      0.018000         0.646       188333   0.837
# 28            28      0.051600         0.782       228562   0.572
# 29            29      0.282000         0.735       186096   0.400
# ...          ...           ...           ...          ...     ...
# 1987        1987      0.028300         0.421       175907   0.831
# 1988        1988      0.000084         0.467       209187   0.794
# 1989        1989      0.000797         0.480       222053   0.826
# 1990        1990      0.000590         0.594       218720   0.858
# 1991        1991      0.000366         0.544       245133   0.788
# 1992        1992      0.007490         0.446       241253   0.881
# 1993        1993      0.001900         0.551       195280   0.732
# 1994        1994      0.510000         0.630       240000   0.772
# 1995        1995      0.020200         0.333       174240   0.913
# 1996        1996      0.003630         0.743       259889   0.889
# 1997        1997      0.000870         0.465       265600   0.953
# 1998        1998      0.031600         0.680       211853   0.725
# 1999        1999      0.004990         0.619       245656   0.949
# 2000        2000      0.093500         0.520       231667   0.809
# 2001        2001      0.002620         0.484       224320   0.609
# 2002        2002      0.030100         0.583       224092   0.891
# 2003        2003      0.000461         0.562       201031   0.960
# 2004        2004      0.096900         0.595       198400   0.975
# 2005        2005      0.021600         0.526       216072   0.825
# 2006        2006      0.178000         0.501       202839   0.683
# 2007        2007      0.002170         0.639       296276   0.978
# 2008        2008      0.054100         0.646       160408   0.714
# 2009        2009      0.004990         0.595       224000   0.837
# 2010        2010      0.002310         0.624       206013   0.971
# 2011        2011      0.000586         0.528       245053   0.879
# 2012        2012      0.001060         0.584       274404   0.932
# 2013        2013      0.087700         0.894       182182   0.892
# 2014        2014      0.008570         0.637       207200   0.935
# 2015        2015      0.001640         0.557       185600   0.992
# 2016        2016      0.002810         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# 25%            0.000000     2.000000     0.092300    -8.394000     0.000000
# 50%            0.000076     6.000000     0.127000    -6.248000     1.000000
# 75%            0.054000     9.000000     0.247000    -4.746000     1.000000
# max            0.976000    11.000000     0.969000    -0.307000     1.000000
#
#        speechiness        tempo  time_signature      valence       target
# count  2017.000000  2017.000000     2017.000000  2017.000000  2017.000000
# mean      0.092664   121.603272        3.968270     0.496815     0.505702
# std       0.089931    26.685604        0.255853     0.247195     0.500091
# min       0.023100    47.859000        1.000000     0.034800     0.000000
# 25%       0.037500   100.189000        4.000000     0.295000     0.000000
# 50%       0.054900   121.427000        4.000000     0.492000     1.000000
# 75%       0.108000   137.849000        4.000000     0.691000     1.000000
# max       0.816000   219.331000        5.000000     0.992000     1.000000

# %%
# transfering acousticness column to different dataset
data1=data["acousticness"]
data1.head()
# Out:
# 0    0.0102
# 1    0.1990
# 2    0.0344
# 3    0.6040
# 4    0.1800
# Name: acousticness, dtype: float64

# %%
data1.mean()
# Out:
# 0.1875900344224095

# %%
data.groupby(['mode']).sum()
# over here we've grouped the data on the basis of Modes the sum parameter adds all the other columns
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms    energy  \
# mode
# 0         753558    129.318399       491.179    198636806  547.5090
# 1        1279578    249.050701       756.178    298162794  827.2321
#
#       instrumentalness   key  liveness  loudness  speechiness       tempo  \
# mode
# 0           112.307261  4877  152.0789 -5378.287      76.8281   96666.741
# 1           156.529650  5899  232.8535 -8913.417     110.0757  148607.058
#
#       time_signature   valence  target
# mode
# 0             3113.0  396.4947     431
# 1             4891.0  605.5812     589

# %%
data.groupby(['mode']).mean()
# over here we've grouped the data on the basis of Modes the sum parameter mean all the other columns
# Out:
#        Unnamed: 0  acousticness  danceability    duration_ms    energy  \
# mode
# 0      963.629156      0.165369      0.628106  254011.260870  0.700139
# 1     1036.095547      0.201660      0.612290  241427.363563  0.669824
#
#       instrumentalness       key  liveness  loudness  speechiness       tempo  \
# mode
# 0             0.143615  6.236573  0.194474 -6.877605     0.098246  123.614758
# 1             0.126745  4.776518  0.188545 -7.217342     0.089130  120.329602
#
#       time_signature   valence    target
# mode
# 0           3.980818  0.507026  0.551151
# 1           3.960324  0.490349  0.476923

# %% [markdown]
# All the major SQL commands can also be performed on the dataset
# There is a method called magic box sql that allows us to change dataset using sql commands
# You can learn more from https://www.geeksforgeeks.org/python-pandas-dataframe/

# %% [markdown]
# # Feature Engineering Dataset

# %% [markdown]
# I've dropped 3 columns to make it easy

# %%
data=data.drop(["song_title","artist","Unnamed: 0","target",],axis=1)

# %% [markdown]
# ## What to do with incomplete dataset

# %% [markdown]
# ### Option 1
# Remove those rows

# %%
data = data.dropna(how='any',axis=0)

# %% [markdown]
# ### Option 2
# Replace the with mean median or mode of the column/row
# For this we need to extract the values from the dataframe and store it in `x`
# I'm considering all values except column 0 and last two columns to i've written `data.loc`
# for extrction integer values we'll write `data.iloc`

# %%
x=data.iloc[:,1:-2].values

# %%
from sklearn.impute import SimpleImputer as Imputer
x=Imputer(missing_values=np.nan, strategy = 'mean').fit_transform(x)

# %% [markdown]
# ### Option 3
# Go and complaint the person who collected :P

# %% [markdown]
# ## What about variation in dataset
# at times on observing the dataset we find that some values are too large and others too small.
# observe above
# duration is too large while acousticness is too small
# to give equal weightage to all the variables we scale them down
# type of scale down also effect the ML models so chose wisely

# %%
from sklearn.preprocessing import StandardScaler
x=StandardScaler().fit_transform(x)
x=pd.DataFrame(x)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.332874 -0.508851 -1.177700 -0.407864 -0.916446 -0.166291 -0.454530
# 1  0.773830  0.983716 -1.534468 -0.465683 -1.190619 -0.346454 -0.881573
# 2  1.363932 -0.739362 -1.282352 -0.487200 -0.916446 -0.204897 -0.016586
# 3 -0.772860 -0.572137 -1.634363  1.379429 -0.093928 -0.634715 -2.167220
# 4  0.370075  1.788484 -0.573574  1.386753 -0.093928  1.596735 -1.213155
#
#           7         8         9
# 0  0.795738  3.763084  1.066709
# 1  0.795738 -0.147529  1.442323
# 2  0.795738  2.183712 -1.745166
# 3  0.795738 -0.740350 -1.316964
# 4 -1.256696 -0.258753  1.964120

# %% [markdown]
# as you can see all the values have now been scaled down
# you can also scale down using these

# %%
df=data
normalized_df=(df-df.mean())/df.std()
normalized_df.head()
# Out:
#    acousticness  danceability  duration_ms    energy  instrumentalness  \
# 0     -0.682298      1.332543    -0.508725 -1.177408         -0.407763
# 1      0.043886      0.773638     0.983472 -1.534087         -0.465568
# 2     -0.589217      1.363594    -0.739179 -1.282034         -0.487079
# 3      1.601643     -0.772668    -0.571995 -1.633957          1.379087
# 4     -0.029194      0.369984     1.788040 -0.573431          1.386409
#
#         key  liveness  loudness      mode  speechiness     tempo  \
# 0 -0.916219 -0.166250 -0.454418  0.795540     3.762151  1.066445
# 1 -1.190324 -0.346368 -0.881354  0.795540    -0.147493  1.441966
# 2 -0.916219 -0.204846 -0.016582  0.795540     2.183171 -1.744734
# 3 -0.093905 -0.634558 -2.166683  0.795540    -0.740166 -1.316638
# 4 -0.093905  1.596339 -1.212855 -1.256384    -0.258689  1.963633
#
#    time_signature   valence
# 0        0.124017 -0.852827
# 1        0.124017  0.368878
# 2        0.124017 -1.309955
# 3        0.124017 -1.079369
# 4        0.124017  1.647219

# %%
normalized_df=(df-df.min())/(df.max()-df.min())
normalized_df.head()
# Out:
#    acousticness  danceability  duration_ms    energy  instrumentalness  \
# 0      0.010248      0.824826     0.190735  0.426363          0.022439
# 1      0.199998      0.720418     0.314481  0.350081          0.006260
# 2      0.034570      0.830626     0.171624  0.403987          0.000240
# 3      0.607034      0.431555     0.185488  0.328723          0.522541
# 4      0.180902      0.645012     0.381202  0.555533          0.524590
#
#         key  liveness  loudness  mode  speechiness     tempo  time_signature  \
# 0  0.181818  0.153862  0.741141   1.0     0.514441  0.596033            0.75
# 1  0.090909  0.124395  0.692162   1.0     0.071005  0.654474            0.75
# 2  0.181818  0.147548  0.791369   1.0     0.335351  0.158539            0.75
# 3  0.454545  0.077247  0.544709   1.0     0.003784  0.225162            0.75
# 4  0.454545  0.442223  0.654132   0.0     0.058393  0.735659            0.75
#
#     valence
# 0  0.262432
# 1  0.577936
# 2  0.144379
# 3  0.203928
# 4  0.908065

# %% [markdown]
# ## Visualization

# %% [markdown]
# An important part of data science include finding relations in a dataset and make also make it easily undestandable for people and your team.
# It also helps us undestand the data and apply appropiate methodolgy to solve it
# Major libraries to make graphs are
# * Seaborn
# * Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lets start by ploting the most import of all
# **HEATMAP**

# %%
plt.figure(figsize=(10,10))
sns.heatmap(normalized_df.corr(),annot=True)

# %% [markdown]
# so what's this
# It shows relation to each column with respect to other
# for example we energy vs accousticness it says -0.56
# which means it has a negative relation, i.e. when one increases other decrease
# similarly look for enery vs loudness  0.72

# %%
plt.bar(x=data["energy"],height=data["loudness"])
plt.xlabel('Energy', fontsize=20)
plt.ylabel('Loudness', fontsize=20)
plt.title('Graph 1')
plt.show()

# %%
plt.scatter(data["energy"],data["loudness"])
plt.xlabel('Energy', fontsize=20)
plt.ylabel('Loudness', fontsize=20)
plt.title('Graph 1')
plt.show()

# %% [markdown]
# There are tonnes of visualization methods and these were the most used ones
# For visualising data you need to change the dataset accordingly
# for more you may visit https://matplotlib.org/tutorials/introductory/sample_plots.html

# %% [markdown]
# # time for an assignmnet
# load the csv in new python notebook
# Data_Science_Topics_Survey.csv
# do feature engineering
# plot the graph
# I know it'll take some time, but its worth devoting

# %%
datagen=pd.read_csv("data/Data_Science_Topics_Survey.csv")
datagen.head()
# Out:
#                    Timestamp  \
# 0  2017/10/17 1:11:52 PM MDT
# 1  2017/10/17 2:26:07 PM MDT
# 2  2017/10/17 2:37:08 PM MDT
# 3  2017/10/17 2:39:26 PM MDT
# 4  2017/10/17 2:43:59 PM MDT
#
#   What's your level of interest for the following areas of Data Science? [Data Visualization]  \
# 0                                    Very interested
# 1                                    Very interested
# 2                                     Not interested
# 3                                    Very interested
# 4                                Somewhat interested
#
#   What's your level of interest for the following areas of Data Science? [Machine Learning]  \
# 0                                    Very interested
# 1                                    Very interested
# 2                                    Very interested
# 3                                    Very interested
# 4                                    Very interested
#
#   What's your level of interest for the following areas of Data Science? [Data Analysis / Statistics]  \
# 0                                Somewhat interested
# 1                                    Very interested
# 2                                Somewhat interested
# 3                                    Very interested
# 4                                    Very interested
#
#   What's your level of interest for the following areas of Data Science? [Big Data (Spark / Hadoop)]  \
# 0                                     Not interested
# 1                                Somewhat interested
# 2                                    Very interested
# 3                                    Very interested
# 4                                    Very interested
#
#   What's your level of interest for the following areas of Data Science? [Data Journalism]  \
# 0                                Somewhat interested
# 1                                     Not interested
# 2                                     Not interested
# 3                                Somewhat interested
# 4                                     Not interested
#
#   What's your level of interest for the following areas of Data Science? [Deep Learning]
# 0                                Somewhat interested
# 1                                    Very interested
# 2                                    Very interested
# 3                                    Very interested
# 4                                Somewhat interested

# %%
# remove column 0

# %%
# take transpose

# %%
# Add columns with same type to give a final product like this

# %%
# complimentary sorting

# %%
#convert it to percentages

# %%
# plot the graph similar to this one
# chose any color
